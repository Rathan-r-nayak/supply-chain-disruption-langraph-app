# %%
print("HIs")
# Out:
# HIs

# %%
from IPython.display import Image, display
from main import build_graph


app = build_graph(all_mcp_tools=[]) # You can pass an empty list just to draw it
display(Image(app.get_graph().draw_mermaid_png()))
# Out:
# INFO | TOOL_NODES | 🔧 Loaded 0 safe tools and 0 sensitive tools. | Line 19

# %%
from IPython.display import Image, display
from Graph.worker_sub_graph import get_worker_subgraph


app = get_worker_subgraph(all_mcp_tools=[]) # You can pass an empty list just to draw it
display(Image(app.get_graph().draw_mermaid_png()))
# Out:
# INFO | TOOL_NODES | 🔧 Loaded 0 safe tools and 0 sensitive tools. | Line 19

# %%
from IPython.display import Image, display
from Graph.rag_sub_graph import get_rag_subgraph
from Graph.worker_sub_graph import get_worker_subgraph


app = get_rag_subgraph() # You can pass an empty list just to draw it
display(Image(app.get_graph().draw_mermaid_png()))
